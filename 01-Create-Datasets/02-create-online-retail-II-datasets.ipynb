# %% [markdown]
# # Online Retail II Data Set
#
# In this notebook we will prepare and store the Online Retail II Data Set stored on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Online+Retail+II)
#
#
# **Citation:**
#
# Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.
#
# ## Download the data
#
# - Navigate to the [data folder](https://archive.ics.uci.edu/ml/machine-learning-databases/00502/).
# - Download the file called **online_retail_II.xlsx**.
# - Save the Excel file into the **datasets** folder at the root of this repository.

# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
# If you downloaded and stored the file as explained
# above, it should be located here:

file = "../Datasets/online_retail_II.xlsx"

# %%
# The data is provided as two sheets in a single Excel file.
# Each sheet contains a different time period.
# Load both and join into a single dataframe.

df_1 = pd.read_excel(file, sheet_name="Year 2009-2010")
df_2 = pd.read_excel(file, sheet_name="Year 2010-2011")

df = pd.concat([df_1, df_2])

# %%
# Inspect dataframe
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                    ...    ...          ...             ...
# 541905 2011-12-09 12:50:00   2.10      12680.0          France
# 541906 2011-12-09 12:50:00   4.15      12680.0          France
# 541907 2011-12-09 12:50:00   4.15      12680.0          France
# 541908 2011-12-09 12:50:00   4.95      12680.0          France
# 541909 2011-12-09 12:50:00  18.00      12680.0          France
#
# [1067371 rows x 8 columns]

# %%
# Rename columns

df.columns = [
    "invoice",
    "stock_code",
    "description",
    "quantity",
    "invoice_date",
    "price",
    "customer_id",
    "country",
]

# %% [markdown]
# # Process data

# %% [markdown]
# Remove null customer ids.

# %%
mask = ~df["customer_id"].isnull()
df = df[mask]

# %% [markdown]
# Create a flag for when an order is cancelled. Cancelled orders contain
# the letter `C` at the start of the invoice.

# %%
df["is_cancelled"] = df["invoice"].apply(lambda x: str(x)[0] == "C")
# Out:
# /var/folders/9g/wztsgzvn6pb5m65md8hxmdrc0000gp/T/ipykernel_31711/24816820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["is_cancelled"] = df["invoice"].apply(lambda x: str(x)[0] == "C")

# %% [markdown]
# Remove transactions which are negative quantities sold and are not cancelled orders.

# %%
mask = ~(~df["is_cancelled"] & df["quantity"] < 0)

df = df[mask]

# %% [markdown]
# Compute revenue.

# %%
df["revenue"] = df["quantity"] * df["price"]

# %%
df["is_cancelled"].value_counts()
# Out:
# False    805620
# True      18744
# Name: is_cancelled, dtype: int64

# %% [markdown]
# To compute gross revenue and quantity sold we filter out cancelled orders.
#
# After this, we resample the data at a weekly level.

# %%
mask = ~df["is_cancelled"]

# If running this raises an UnsupportedFunctionCall error
# try upgrading your version of pandas.
df_gross = (
    df.loc[mask, ["invoice_date", "quantity", "revenue", "country"]]
    .groupby("country")
    .resample("W", on="invoice_date")
    .sum(numeric_only=True)
)

# %%
df.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# price                  float64
# customer_id            float64
# country                 object
# is_cancelled              bool
# revenue                float64
# dtype: object

# %%
df_gross
# Out:
#                           quantity  revenue
# country     invoice_date
# Australia   2009-12-06         100   196.10
#             2009-12-13           0     0.00
#             2009-12-20          60    75.00
#             2009-12-27           0     0.00
#             2010-01-03           0     0.00
# ...                            ...      ...
# Unspecified 2011-08-07           0     0.00
#             2011-08-14           0     0.00
#             2011-08-21           0     0.00
#             2011-08-28         185   531.03
# West Indies 2010-08-29         395   536.41
#
# [3111 rows x 2 columns]

# %%
df_gross.index.rename(["country", "week"], inplace=True)

# %% [markdown]
# # Save data
#
# We will save 3 different versions of the preprocessed dataset for different demos.
#
# ## Weekly sampled

# %%
df_gross_countries = df_gross.reset_index(level="country")

# %%
countries = [
    'United Kingdom',
    'Belgium',
    "EIRE",
    'Germany',
    "France",
    'Spain',
]

# %%
df_gross_countries[df_gross_countries["country"].isin(countries)].to_csv(
    "../Datasets/online_retail_dataset_countries.csv",
    index=True,
)

# %% [markdown]
# ## Unstacked countries

# %%
y = df_gross.unstack("country")["revenue"]

# %%
assert y.sort_index().equals(df_gross.reset_index().pivot(columns="country", index="week", values="revenue").sort_index())

# %%
y
# Out:
# country     Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# week
# 2009-12-06      196.1      NaN      NaN   439.10     NaN     NaN
# 2009-12-13        0.0  1429.83      NaN     8.50     NaN     NaN
# 2009-12-20       75.0     0.00      NaN     0.00     NaN     NaN
# 2009-12-27        0.0   568.51      NaN     0.00     NaN     NaN
# 2010-01-03        0.0     0.00      NaN     0.00     NaN     NaN
# ...               ...      ...      ...      ...     ...     ...
# 2011-11-13        0.0   586.85      NaN  1261.05     NaN     NaN
# 2011-11-20     5355.4   742.93      NaN  2798.53     NaN     NaN
# 2011-11-27      286.4     0.00      NaN   301.25     NaN     NaN
# 2011-12-04        NaN     0.00      NaN   592.22     NaN     NaN
# 2011-12-11        NaN   683.20      NaN  1107.41     NaN     NaN
#
# country     Channel Islands   Cyprus  Czech Republic  Denmark  ...  Singapore  \
# week                                                           ...
# 2009-12-06           989.18   760.69             NaN  1008.00  ...        NaN
# 2009-12-13             0.00     0.00             NaN     0.00  ...        NaN
# 2009-12-20             0.00  2796.29             NaN   429.66  ...        NaN
# 2009-12-27             0.00     0.00             NaN     0.00  ...        NaN
# 2010-01-03             0.00     0.00             NaN     0.00  ...        NaN
# ...                     ...      ...             ...      ...  ...        ...
# 2011-11-13             0.00     0.00             NaN     0.00  ...        NaN
# 2011-11-20           211.63   460.89             NaN  1794.05  ...        NaN
# 2011-11-27             0.00      NaN             NaN     0.00  ...        NaN
# 2011-12-04             0.00      NaN             NaN   905.52  ...        NaN
# 2011-12-11           198.40      NaN             NaN   168.90  ...        NaN
#
# country       Spain   Sweden  Switzerland  Thailand     USA  \
# week
# 2009-12-06   435.88      NaN          NaN       NaN  141.00
# 2009-12-13   412.60   285.30          NaN       NaN    0.00
# 2009-12-20  1952.64     0.00       589.40       NaN    0.00
# 2009-12-27  5149.06     0.00         0.00       NaN    0.00
# 2010-01-03     0.00     0.00         0.00       NaN    0.00
# ...             ...      ...          ...       ...     ...
# 2011-11-13  1522.70   223.68       292.58       NaN    0.00
# 2011-11-20  2278.29  1420.14       925.64       NaN    0.00
# 2011-11-27  3595.96   406.72       430.57       NaN    0.00
# 2011-12-04   170.74     0.00       262.50       NaN  269.96
# 2011-12-11   316.21   238.00          NaN       NaN  615.28
#
# country     United Arab Emirates  United Kingdom  Unspecified  West Indies
# week
# 2009-12-06                   NaN       213000.35          NaN          NaN
# 2009-12-13                 517.7       195810.04          NaN          NaN
# 2009-12-20                   0.0       182396.74          NaN          NaN
# 2009-12-27                   0.0        22007.77          NaN          NaN
# 2010-01-03                   0.0            0.00          NaN          NaN
# ...                          ...             ...          ...          ...
# 2011-11-13                   NaN       229378.01          NaN          NaN
# 2011-11-20                   NaN       221870.29          NaN          NaN
# 2011-11-27                   NaN       210741.76          NaN          NaN
# 2011-12-04                   NaN       220213.99          NaN          NaN
# 2011-12-11                   NaN       372946.26          NaN          NaN
#
# [106 rows x 41 columns]

# %%
y.to_csv("../Datasets/online_retail_dataset.csv")

# %% [markdown]
# ## Raw data

# %%
# columns needed for demo
cols = ["invoice_date", "description", "revenue"]

# just UK
df = df[df["country"] == "United Kingdom"]

# save
df[cols].to_csv("../Datasets/online_retail_dataset_all.csv", index=False)
